# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping
import warnings
warnings.filterwarnings('ignore')

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
df = pd.read_csv('taylor_swift_lyrics.csv', encoding='latin-1')
print("Shape:", df.shape)
print("Columns:", df.columns.tolist())
df.head()
# Out:
# Shape: (4862, 7)
# Columns: ['artist', 'album', 'track_title', 'track_n', 'lyric', 'line', 'year']
#          artist         album track_title  track_n  \
# 0  Taylor Swift  Taylor Swift  Tim McGraw        1
# 1  Taylor Swift  Taylor Swift  Tim McGraw        1
# 2  Taylor Swift  Taylor Swift  Tim McGraw        1
# 3  Taylor Swift  Taylor Swift  Tim McGraw        1
# 4  Taylor Swift  Taylor Swift  Tim McGraw        1
#
#                                          lyric  line  year
# 0          He said the way my blue eyes shined     1  2006
# 1  Put those Georgia stars to shame that night     2  2006
# 2                       I said, "That's a lie"     3  2006
# 3                  Just a boy in a Chevy truck     4  2006
# 4         That had a tendency of gettin' stuck     5  2006

# %%
print("Albums:", df['album'].unique())
print("Years:", sorted(df['year'].unique()))
print("Total lyrics lines:", len(df))
print("Total songs:", df['track_title'].nunique())
# Out:
# Albums: ['Taylor Swift' 'Fearless' 'Speak Now' 'Red' '1989' 'reputation']
# Years: [np.int64(2006), np.int64(2008), np.int64(2010), np.int64(2012), np.int64(2014), np.int64(2017)]
# Total lyrics lines: 4862
# Total songs: 94

# %%
df.head()
# Out:
#          artist         album track_title  track_n  \
# 0  Taylor Swift  Taylor Swift  Tim McGraw        1
# 1  Taylor Swift  Taylor Swift  Tim McGraw        1
# 2  Taylor Swift  Taylor Swift  Tim McGraw        1
# 3  Taylor Swift  Taylor Swift  Tim McGraw        1
# 4  Taylor Swift  Taylor Swift  Tim McGraw        1
#
#                                          lyric  line  year
# 0          He said the way my blue eyes shined     1  2006
# 1  Put those Georgia stars to shame that night     2  2006
# 2                       I said, "That's a lie"     3  2006
# 3                  Just a boy in a Chevy truck     4  2006
# 4         That had a tendency of gettin' stuck     5  2006

# %%
import re
def clean_text(text):
    text = text.lower()
    text = re.sub(r'\[.*?\]', '', text)
    text = re.sub(r'[^a-z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

all_lyrics = ' '.join(df['lyric'].dropna().tolist())
corpus = clean_text(all_lyrics)

print(f"Total characters : {len(corpus)}")
print(f"Sample : {corpus[:300]}")
# Out:
# Total characters : 167705
# Sample : he said the way my blue eyes shined put those georgia stars to shame that night i said thats a lie just a boy in a chevy truck that had a tendency of gettin stuck on backroads at night and i was right there beside him all summer long and then the time we woke up to find that summer gone but when you

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts([corpus])

total_words = len(tokenizer.word_index) + 1
print(f"Vocabulary size : {total_words}")
# Out:
# Vocabulary size : 2381

# %%
input_sequences = []

for line in df['lyric'].dropna():
    line_clean = clean_text(line)
    token_list = tokenizer.texts_to_sequences([line_clean])[0]
    
    for i in range(1, len(token_list)):
        n_gram = token_list[:i+1]
        input_sequences.append(n_gram)

print(f" Total sequences : {len(input_sequences)}")
# Out:
#  Total sequences : 30344

# %%
SEQ_LENGTH = 20

input_sequences_padded = pad_sequences(
    input_sequences,
    maxlen=SEQ_LENGTH,
    padding='pre'
)

X = input_sequences_padded[:, :-1]
y = input_sequences_padded[:, -1]

print(f" SEQ_LENGTH : {SEQ_LENGTH}")
print(f" X shape : {X.shape}")
print(f" y shape avant to_categorical : {y.shape}")
# Out:
#  SEQ_LENGTH : 20
#  X shape : (30344, 19)
#  y shape avant to_categorical : (30344,)

# %%
from tensorflow.keras.utils import to_categorical

y = to_categorical(y, num_classes=total_words)

print(f" X shape : {X.shape}")
print(f" y shape : {y.shape}")
# Out:
#  X shape : (30344, 19)
#  y shape : (30344, 2381)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import warnings
warnings.filterwarnings('ignore')

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical        
from tensorflow.keras.callbacks import EarlyStopping

print(" Tous les imports OK !")
# Out:
#  Tous les imports OK !

# %%
model = Sequential([
    Embedding(input_dim=total_words, output_dim=100, input_length=SEQ_LENGTH-1),
    LSTM(150, return_sequences=True),
    Dropout(0.2),
    LSTM(100),
    Dropout(0.2),
    Dense(total_words, activation='softmax')
])

model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ ?                      │             0 │
# ...

# %%
early_stop = EarlyStopping(
    monitor='loss',
    patience=5,
    restore_best_weights=True
)

history = model.fit(
    X, y,
    epochs=50,
    batch_size=64,
    callbacks=[early_stop],
    verbose=1
)

print(" Entraînement terminé !")
# Out:
# Epoch 1/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 30s 62ms/step - accuracy: 0.3963 - loss: 2.7133
# Epoch 2/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 33s 70ms/step - accuracy: 0.4009 - loss: 2.7047
# Epoch 3/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 31s 65ms/step - accuracy: 0.4051 - loss: 2.6674
# Epoch 4/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 30s 63ms/step - accuracy: 0.4100 - loss: 2.6605
# Epoch 5/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 29s 62ms/step - accuracy: 0.4068 - loss: 2.6349
# Epoch 6/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 30s 64ms/step - accuracy: 0.4168 - loss: 2.6072
# Epoch 7/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 30s 63ms/step - accuracy: 0.4287 - loss: 2.5749
# Epoch 8/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 29s 62ms/step - accuracy: 0.4209 - loss: 2.6048
# Epoch 9/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 29s 61ms/step - accuracy: 0.4279 - loss: 2.5709
# Epoch 10/50
# 475/475 ━━━━━━━━━━━━━━━━━━━━ 35s 73ms/step - accuracy: 0.4298 - loss: 2.5498
# Epoch 11/50
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(history.history['loss'], color='#e91e8c', linewidth=2)
axes[0].set_title('Loss')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].grid(True, alpha=0.3)

axes[1].plot(history.history['accuracy'], color='#9c27b0', linewidth=2)
axes[1].set_title('Accuracy')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].grid(True, alpha=0.3)

plt.suptitle('Taylor Swift LSTM - Training', fontsize=16)
plt.tight_layout()
plt.savefig('training_curves.png', dpi=150)
plt.show()

# %%
def generate_lyrics(seed_text, next_words=30, temperature=0.8):
    result = seed_text
    
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences(
            [token_list],
            maxlen=SEQ_LENGTH-1,
            padding='pre'
        )
        
        predictions = model.predict(token_list, verbose=0)[0]
        predictions = np.log(predictions + 1e-10) / temperature
        predictions = np.exp(predictions) / np.sum(np.exp(predictions))
        
        predicted_index = np.random.choice(len(predictions), p=predictions)
        output_word = tokenizer.index_word.get(predicted_index, "")
        
        seed_text += " " + output_word
        result += " " + output_word
    
    return result


seeds = [
    "i knew you were trouble",
    "we are never getting back together",
    "shake it off"
]

print("=" * 60)
print(" GENERATED TAYLOR SWIFT LYRICS")
print("=" * 60)

for seed in seeds:
    print(f"\n Seed : '{seed}'")
    print("-" * 40)
    print(generate_lyrics(seed, next_words=25, temperature=0.8))
# Out:
# ...
#  GENERATED TAYLOR SWIFT LYRICS
# ...
#
#  Seed : 'i knew you were trouble'
# ----------------------------------------
# i knew you were trouble hold on to my seven dwarfs you want yeah i dont go on your love silence i love is all this time that love it
#
#  Seed : 'we are never getting back together'
# ----------------------------------------
# we are never getting back together down all fades in time to say what you tell me you love you want your stand in the rain outside down the water rushes
#
#  Seed : 'shake it off'
# ----------------------------------------
# shake it off i shake it off i shake it off i would i wish you fight it do you never said far this back of me now

# %%
print(" Effet de la température sur la génération :\n")

for temp in [0.5, 1.0, 1.5]:
    print(f"Temperature = {temp} :")
    result = generate_lyrics("shake it off", next_words=20, temperature=temp)
    print(f"  → {result}\n")
# Out:
#  Effet de la température sur la génération :
#
# Temperature = 0.5 :
#   → shake it off i shake it off i shake it off i shake it off i shake it off you leave me you
#
# Temperature = 1.0 :
#   → shake it off i shake it off i shake it off i shake it off i shake it off you love it i
#
# Temperature = 1.5 :
#   → shake it off theres so rumors youre tired of wishing your never team a deadend wide team to me loved when it off

# %%
model.save('taylor_swift_lstm.keras')
print(" Modèle sauvegardé en format .keras !")
# Out:
#  Modèle sauvegardé en format .keras !
